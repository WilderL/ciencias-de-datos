# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
dta = sm.datasets.co2.load_pandas().data

# %%
dta.plot()
plt.title('Niveles de CO2')
plt.ylabel('Partes por millon')
plt.xlabel('Año')
plt.show()

# %%
dta
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %%
##pip install yfinance
import urllib
import numpy as np
import yfinance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import urllib
#       3 import numpy as np
# ----> 4 import yfinance
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
ticker_google = 'GOOGL'
start_date = '2025-01-01'
end_date = '2025-12-31'
df_google = yf.dowload(ticker, start=start_date, end=end_date)
